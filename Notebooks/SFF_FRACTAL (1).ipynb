# %%
# ==============================================================================
# CELDA 1: INSTALACIÓN Y CONFIGURACIÓN (CON CUDA 12.x)
# ==============================================================================

# Instalar CuPy para CUDA 12.x
# !pip uninstall -y cupy cupy-cuda11x cupy-cuda12x -q
# !pip install cupy-cuda12x -q

import os
import numpy as np
import cupy as cp
import matplotlib.pyplot as plt
from scipy.special import lambertw
from scipy.stats import linregress
from scipy.interpolate import UnivariateSpline
import gc
import time
import psutil

# Verificar GPU
print("🔍 VERIFICACIÓN DE GPU:")
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
print(f"\n✅ CuPy usando: {cp.cuda.runtime.getDeviceProperties(0)['name'].decode()}")

# Constantes
EPSILON_CRITICAL = np.pi * np.sqrt(2)
NU_EXPONENT = 0.75
T_HEISENBERG = 2 * np.pi
PHASE_SHIFT = 7/8
N_SIZE = 15000
M_REALIZATIONS = 100

print(f"\n📐 PARÁMETROS:")
print(f"   ε_crit = {EPSILON_CRITICAL:.6f}")
print(f"   ν = {NU_EXPONENT}")
print(f"   N = {N_SIZE}, M = {M_REALIZATIONS}")
# Out:
# WARNING: Skipping cupy as it is not installed.
# WARNING: Skipping cupy-cuda11x as it is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 MB 7.6 MB/s eta 0:00:00
# 🔍 VERIFICACIÓN DE GPU:
# Tesla T4, 15360 MiB, 14913 MiB
#
# ✅ CuPy usando: Tesla T4
#
# 📐 PARÁMETROS:
#    ε_crit = 4.442883
#    ν = 0.75
#    N = 15000, M = 100

# %%
# ------------------------------------------------------------------------------
# CELDA 2: CONSTANTES FUNDAMENTALES (derivadas analíticamente)
# ------------------------------------------------------------------------------
EPSILON_CRITICAL = np.pi * np.sqrt(2)      # ε = π√2 (resonancia termodinámica)
NU_EXPONENT = 0.75                          # ν = 0.75 (centro fase extendida)
T_HEISENBERG = 2 * np.pi                     # t_H = 2π
PHASE_SHIFT = 7/8                            # Corrección topológica 7/8
N_SIZE = 15000                                # Dimensión de la matriz
M_REALIZATIONS = 100                          # Número de realizaciones

print(f"\n📐 PARÁMETROS FUNDAMENTALES:")
print(f"   ε_crit = {EPSILON_CRITICAL:.6f} (derivado de 2ε² = (2π)²)")
print(f"   ν = {NU_EXPONENT} (Kato-Rellich bound: ν > 0.5)")
print(f"   Máscara modular: d ≡ 1,5 (mod 6) [canales primos]")
print(f"   t_H = {T_HEISENBERG:.4f}")
print(f"   N = {N_SIZE}, M = {M_REALIZATIONS}")
# Out:
# 📐 PARÁMETROS FUNDAMENTALES:
#    ε_crit = 4.442883 (derivado de 2ε² = (2π)²)
#    ν = 0.75 (Kato-Rellich bound: ν > 0.5)
#    Máscara modular: d ≡ 1,5 (mod 6) [canales primos]
#    t_H = 6.2832
#    N = 15000, M = 100

# %%
# ------------------------------------------------------------------------------
# CELDA 3: CONSTRUCCIÓN DEL HAMILTONIANO EN GPU (OPTIMIZADO)
# ------------------------------------------------------------------------------
def build_hamiltonian_gpu(N, epsilon=EPSILON_CRITICAL, nu=NU_EXPONENT):
    """
    Construye H = H_0 + V en GPU con:
    - H_0: potencial diagonal exacto vía Lambert W
    - V: interacciones PRBM con máscara χ₀⁽⁶⁾(d) ∈ {1,5}
    """
    # Inicializar matriz en GPU (complex64 para ahorrar memoria)
    H = cp.zeros((N, N), dtype=cp.complex64)

    # 1. DIAGONAL EXACTA (vectorizada en CPU por lambertw, luego transferida)
    k = np.arange(2, N + 2, dtype=np.float64)
    k_eff = k - PHASE_SHIFT
    lambert_vals = np.real(lambertw(k_eff / np.e))
    diag = (2 * np.pi * k_eff) / lambert_vals
    cp.fill_diagonal(H, cp.asarray(diag, dtype=cp.complex64))

    # 2. INTERACCIONES (procesamiento por batches en GPU)
    # Pre-calcular todas las distancias permitidas
    max_d = N - 1
    allowed_d = cp.array([d for d in range(1, max_d + 1) if d % 6 in (1, 5)], dtype=cp.int32)

    total_elems = 0
    # Procesar en batches para mejor uso de GPU
    batch_size = 50

    for i in range(0, len(allowed_d), batch_size):
        d_batch = allowed_d[i:i+batch_size]

        for d in d_batch:
            d_int = int(d)  # Convertir a entero Python para operaciones
            num_elems = N - d_int

            if num_elems <= 0:
                continue

            # Generar ruido GUE en GPU (mucho más rápido)
            real_parts = cp.random.normal(0, 1/np.sqrt(2), num_elems, dtype=cp.float32)
            imag_parts = cp.random.normal(0, 1/np.sqrt(2), num_elems, dtype=cp.float32)
            G = real_parts + 1j * imag_parts

            # Decaimiento espacial (operación en GPU)
            decay = cp.power(d, -nu, dtype=cp.float32)
            vals = epsilon * decay * G

            # Índices
            i_idx = cp.arange(num_elems, dtype=cp.int32)
            j_idx = i_idx + d_int

            # Asignación hermítica
            H[i_idx, j_idx] = vals
            H[j_idx, i_idx] = cp.conj(vals)

            total_elems += num_elems

        if (i // batch_size) % 5 == 0:
            print(f"      Procesadas {i+len(d_batch)}/{len(allowed_d)} distancias")

    print(f"   ✅ Total elementos no-diagonales: {total_elems}")
    return H

# %%
# ------------------------------------------------------------------------------
# CELDA 4: UNFOLDING Y SFF (VERSIONES GPU/CPU HÍBRIDAS)
# ------------------------------------------------------------------------------
def unfold_spectrum(evals_cpu):
    """
    Unfolding con desplazamiento invariante bajo traslaciones.
    Opera en CPU (datos ya transferidos).
    """
    evals_min = np.min(evals_cpu)
    if evals_min <= 0:
        evals_shifted = evals_cpu - evals_min + 1e-6
    else:
        evals_shifted = evals_cpu

    unfolded = (evals_shifted / (2 * np.pi)) * np.log(evals_shifted / (2 * np.pi * np.e))
    return unfolded

def calculate_sff_gpu(w_n_cpu, t_values):
    """
    Calcula K(t) usando GPU para la parte intensiva.
    w_n_cpu: array CPU con los niveles unfolded
    t_values: array CPU con los tiempos
    """
    # Transferir a GPU
    w_n_gpu = cp.asarray(w_n_cpu, dtype=cp.float64)
    t_gpu = cp.asarray(t_values, dtype=cp.float64)

    # Calcular fases en GPU (producto exterior optimizado)
    # Usamos batch processing para no agotar memoria
    batch_size = 1000
    K_t = cp.zeros(len(t_values), dtype=cp.float64)

    for i in range(0, len(t_values), batch_size):
        i_end = min(i + batch_size, len(t_values))
        t_batch = t_gpu[i:i_end]

        # phases shape: (len(w_n), len(t_batch))
        phases = cp.exp(1j * cp.outer(w_n_gpu, t_batch))
        K_t[i:i_end] = cp.abs(cp.sum(phases, axis=0))**2 / len(w_n_gpu)

    return cp.asnumpy(K_t)

# %%
# ------------------------------------------------------------------------------
# CELDA 5: DETECCIÓN ROBUSTA DE DIP Y RAMPA
# ------------------------------------------------------------------------------
def detect_ramp_parameters(t_values, K_values):
    """
    Detecta automáticamente el dip y el rango óptimo de la rampa
    basado en curvatura mínima.
    """
    log_t = np.log(t_values)
    log_K = np.log(K_values)

    # 1. Detectar dip con spline
    spline = UnivariateSpline(log_t, log_K, s=len(t_values)*0.02)
    log_t_fine = np.linspace(log_t[0], log_t[-1], 1000)
    log_K_fine = spline(log_t_fine)

    idx_dip = np.argmin(log_K_fine)
    t_dip = np.exp(log_t_fine[idx_dip])
    K_dip = np.exp(log_K_fine[idx_dip])

    # 2. Encontrar región de mínima curvatura (más lineal)
    curvature = np.abs(np.gradient(np.gradient(log_K_fine, log_t_fine), log_t_fine))
    curvature = curvature / np.max(curvature)  # normalizar

    # Umbral adaptativo
    threshold = 0.2
    flat_regions = curvature < threshold

    if np.any(flat_regions):
        # Tomar la región plana más larga
        from itertools import groupby
        regions = []
        for k, g in groupby(enumerate(flat_regions), lambda x: x[1]):
            if k:
                indices = [idx for idx, _ in g]
                regions.append((indices[0], indices[-1]))

        longest = max(regions, key=lambda r: r[1] - r[0])
        idx_start, idx_end = longest

        t_min_ramp = np.exp(log_t_fine[idx_start])
        t_max_ramp = np.exp(log_t_fine[idx_end])
    else:
        # Fallback a heurística
        t_min_ramp = max(1.2 * t_dip, 0.5)
        t_max_ramp = 0.7 * T_HEISENBERG

    ramp_mask = (t_values > t_min_ramp) & (t_values < t_max_ramp)

    return t_dip, K_dip, ramp_mask

# %%
# ------------------------------------------------------------------------------
# CELDA 6: BUCLE PRINCIPAL DEL ENSAMBLE (CON CHECKPOINTING)
# ------------------------------------------------------------------------------
def run_ensemble_gpu():
    """Ejecuta el ensamble completo en GPU con checkpointing"""

    checkpoint_file = 'ensemble_checkpoint.npz'
    t_values = np.logspace(-1.5, np.log10(3*np.pi), 500)

    # Intentar cargar checkpoint
    start_m = 0
    K_total = np.zeros(len(t_values), dtype=np.float64)
    D2_list = []

    if os.path.exists(checkpoint_file):
        data = np.load(checkpoint_file)
        K_total = data['K_total']
        D2_list = data['D2_list'].tolist()
        start_m = len(D2_list)
        print(f"📦 Checkpoint cargado: {start_m}/{M_REALIZATIONS} realizaciones")

    print(f"\n🚀 Iniciando ensamble desde realización {start_m+1}")
    print("="*70)

    total_start = time.time()

    for m in range(start_m, M_REALIZATIONS):
        t0 = time.time()
        print(f"\n📊 Realización {m+1}/{M_REALIZATIONS}")

        # 1. Construir Hamiltoniano en GPU
        print(f"   Construyendo matriz...")
        H_gpu = build_hamiltonian_gpu(N_SIZE)

        # 2. Diagonalización en GPU
        print(f"   Diagonalizando...")
        t_eig0 = time.time()
        evals_gpu, evecs_gpu = cp.linalg.eigh(H_gpu)
        t_eig1 = time.time()
        print(f"   ⏱️  Diagonalización: {t_eig1-t_eig0:.2f}s")

        # 3. Transferir a CPU para post-procesado
        evals = cp.asnumpy(evals_gpu)

        # 4. Liberar memoria GPU de la matriz (importante)
        del H_gpu
        cp.get_default_memory_pool().free_all_blocks()

        # 5. Unfolding (CPU)
        w_n = unfold_spectrum(evals)

        # 6. SFF (GPU)
        K_t = calculate_sff_gpu(w_n, t_values)
        K_total += K_t

        # 7. Dimensión fractal D₂ (usando autovectores)
        evecs = cp.asnumpy(evecs_gpu)
        del evecs_gpu

        bulk_start = int(0.25 * N_SIZE)
        bulk_end = int(0.75 * N_SIZE)
        bulk_evecs = evecs[:, bulk_start:bulk_end]

        ipr = np.mean(np.sum(np.abs(bulk_evecs)**4, axis=0))
        D2 = -np.log(ipr) / np.log(N_SIZE)
        D2_list.append(D2)

        # 8. Limpieza
        del evals, evecs, bulk_evecs, w_n, K_t
        gc.collect()

        # 9. Estadísticas
        t1 = time.time()
        elapsed = t1 - t0
        total_elapsed = t1 - total_start
        avg_time = np.mean([t1 - t0 for _ in range(m+1)])
        remaining = (M_REALIZATIONS - (m + 1)) * avg_time

        print(f"   ✅ D₂ = {D2:.4f} | Media D₂ = {np.mean(D2_list):.4f} ± {np.std(D2_list):.4f}")
        print(f"   ⏱️  Esta: {elapsed:.2f}s | Total: {total_elapsed/60:.2f} min | Restante: {remaining/60:.2f} min")

        # 10. Checkpoint cada 5 realizaciones
        if (m + 1) % 5 == 0:
            np.savez(checkpoint_file,
                     K_total=K_total,
                     D2_list=np.array(D2_list))
            print(f"   💾 Checkpoint guardado")

    # Resultados finales
    K_avg = K_total / M_REALIZATIONS
    D2_mean = np.mean(D2_list)
    D2_std = np.std(D2_list)

    return t_values, K_avg, D2_mean, D2_std, D2_list

# %%
# ------------------------------------------------------------------------------
# CELDA 7: EJECUCIÓN PRINCIPAL
# ------------------------------------------------------------------------------
print("\n" + "="*70)
print("🎯 INICIANDO VALIDACIÓN NEE EN T4 GPU")
print("="*70)

t_values, K_avg, D2_mean, D2_std, D2_list = run_ensemble_gpu()
# Out:
# ======================================================================
# 🎯 INICIANDO VALIDACIÓN NEE EN T4 GPU
# ======================================================================
#
# 🚀 Iniciando ensamble desde realización 1
# ======================================================================
#
# 📊 Realización 1/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 37.00s
#    ✅ D₂ = 0.2438 | Media D₂ = 0.2438 ± 0.0000
#    ⏱️  Esta: 51.57s | Total: 0.86 min | Restante: 85.08 min
#
# 📊 Realización 2/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 27.85s
#    ✅ D₂ = 0.2430 | Media D₂ = 0.2434 ± 0.0004
#    ⏱️  Esta: 41.32s | Total: 1.55 min | Restante: 67.49 min
#
# 📊 Realización 3/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 28.40s
#    ✅ D₂ = 0.2440 | Media D₂ = 0.2436 ± 0.0004
#    ⏱️  Esta: 42.38s | Total: 2.25 min | Restante: 68.51 min
#
# 📊 Realización 4/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 29.70s
#    ✅ D₂ = 0.2425 | Media D₂ = 0.2433 ± 0.0006
#    ⏱️  Esta: 44.82s | Total: 3.00 min | Restante: 71.71 min
#
# 📊 Realización 5/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.88s
#    ✅ D₂ = 0.2433 | Media D₂ = 0.2433 ± 0.0005
#    ⏱️  Esta: 45.79s | Total: 3.76 min | Restante: 72.50 min
#    💾 Checkpoint guardado
#
# 📊 Realización 6/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.69s
#    ✅ D₂ = 0.2441 | Media D₂ = 0.2434 ± 0.0006
#    ⏱️  Esta: 45.79s | Total: 4.53 min | Restante: 71.74 min
#
# 📊 Realización 7/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.71s
#    ✅ D₂ = 0.2428 | Media D₂ = 0.2433 ± 0.0006
#    ⏱️  Esta: 45.57s | Total: 5.29 min | Restante: 70.64 min
#
# 📊 Realización 8/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.69s
#    ✅ D₂ = 0.2436 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.94s | Total: 6.05 min | Restante: 70.43 min
#
# 📊 Realización 9/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.68s
#    ✅ D₂ = 0.2430 | Media D₂ = 0.2433 ± 0.0005
#    ⏱️  Esta: 45.47s | Total: 6.81 min | Restante: 68.96 min
#
# 📊 Realización 10/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.84s
#    ✅ D₂ = 0.2435 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.67s | Total: 7.57 min | Restante: 68.50 min
#    💾 Checkpoint guardado
#
# 📊 Realización 11/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.71s
#    ✅ D₂ = 0.2437 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 46.17s | Total: 8.34 min | Restante: 68.48 min
#
# 📊 Realización 12/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.66s
#    ✅ D₂ = 0.2442 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.40s | Total: 9.10 min | Restante: 66.59 min
#
# 📊 Realización 13/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.76s
#    ✅ D₂ = 0.2435 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.65s | Total: 9.86 min | Restante: 66.19 min
#
# 📊 Realización 14/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.79s
#    ✅ D₂ = 0.2429 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 46.19s | Total: 10.63 min | Restante: 66.20 min
#
# 📊 Realización 15/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.72s
#    ✅ D₂ = 0.2427 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.54s | Total: 11.39 min | Restante: 64.52 min
#    💾 Checkpoint guardado
#
# 📊 Realización 16/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.65s
#    ✅ D₂ = 0.2439 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.66s | Total: 12.15 min | Restante: 63.92 min
#
# 📊 Realización 17/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.68s
#    ✅ D₂ = 0.2432 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.81s | Total: 12.91 min | Restante: 63.38 min
#
# 📊 Realización 18/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.75s
#    ✅ D₂ = 0.2437 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.93s | Total: 13.68 min | Restante: 62.78 min
#
# 📊 Realización 19/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.73s
#    ✅ D₂ = 0.2438 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.78s | Total: 14.44 min | Restante: 61.80 min
#
# 📊 Realización 20/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.74s
#    ✅ D₂ = 0.2446 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.52s | Total: 15.20 min | Restante: 60.69 min
#    💾 Checkpoint guardado
#
# 📊 Realización 21/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.74s
#    ✅ D₂ = 0.2443 | Media D₂ = 0.2435 ± 0.0006
#    ⏱️  Esta: 46.19s | Total: 15.97 min | Restante: 60.82 min
#
# 📊 Realización 22/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.67s
#    ✅ D₂ = 0.2435 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.42s | Total: 16.73 min | Restante: 59.05 min
#
# 📊 Realización 23/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.72s
#    ✅ D₂ = 0.2435 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.56s | Total: 17.49 min | Restante: 58.47 min
#
# 📊 Realización 24/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.77s
#    ✅ D₂ = 0.2441 | Media D₂ = 0.2436 ± 0.0005
#    ⏱️  Esta: 46.20s | Total: 18.26 min | Restante: 58.51 min
#
# 📊 Realización 25/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.63s
#    ✅ D₂ = 0.2425 | Media D₂ = 0.2435 ± 0.0006
#    ⏱️  Esta: 45.50s | Total: 19.01 min | Restante: 56.88 min
#    💾 Checkpoint guardado
#
# 📊 Realización 26/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.74s
#    ✅ D₂ = 0.2436 | Media D₂ = 0.2435 ± 0.0006
#    ⏱️  Esta: 45.51s | Total: 19.77 min | Restante: 56.13 min
#
# 📊 Realización 27/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.56s
#    ✅ D₂ = 0.2430 | Media D₂ = 0.2435 ± 0.0006
#    ⏱️  Esta: 45.99s | Total: 20.54 min | Restante: 55.96 min
#
# 📊 Realización 28/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.61s
#    ✅ D₂ = 0.2437 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.38s | Total: 21.30 min | Restante: 54.45 min
#
# 📊 Realización 29/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.69s
#    ✅ D₂ = 0.2429 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.50s | Total: 22.05 min | Restante: 53.84 min
#
# 📊 Realización 30/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.64s
#    ✅ D₂ = 0.2440 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 46.06s | Total: 22.82 min | Restante: 53.73 min
#    💾 Checkpoint guardado
#
# 📊 Realización 31/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.60s
#    ✅ D₂ = 0.2431 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.25s | Total: 23.58 min | Restante: 52.04 min
#
# 📊 Realización 32/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.71s
#    ✅ D₂ = 0.2438 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.80s | Total: 24.34 min | Restante: 51.90 min
#
# 📊 Realización 33/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.73s
#    ✅ D₂ = 0.2430 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.86s | Total: 25.10 min | Restante: 51.21 min
#
# 📊 Realización 34/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.60s
#    ✅ D₂ = 0.2428 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.55s | Total: 25.86 min | Restante: 50.10 min
#
# 📊 Realización 35/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.73s
#    ✅ D₂ = 0.2438 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.72s | Total: 26.62 min | Restante: 49.53 min
#    💾 Checkpoint guardado
#
# 📊 Realización 36/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.73s
#    ✅ D₂ = 0.2431 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.68s | Total: 27.39 min | Restante: 48.72 min
#
# 📊 Realización 37/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.72s
#    ✅ D₂ = 0.2446 | Media D₂ = 0.2435 ± 0.0006
#    ⏱️  Esta: 45.95s | Total: 28.15 min | Restante: 48.25 min
#
# 📊 Realización 38/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.65s
#    ✅ D₂ = 0.2428 | Media D₂ = 0.2435 ± 0.0006
#    ⏱️  Esta: 45.55s | Total: 28.91 min | Restante: 47.07 min
#
# 📊 Realización 39/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.88s
#    ✅ D₂ = 0.2436 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.84s | Total: 29.67 min | Restante: 46.60 min
#
# 📊 Realización 40/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.58s
#    ✅ D₂ = 0.2432 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 46.09s | Total: 30.44 min | Restante: 46.09 min
#    💾 Checkpoint guardado
#
# 📊 Realización 41/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.67s
#    ✅ D₂ = 0.2436 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.43s | Total: 31.20 min | Restante: 44.67 min
#
# 📊 Realización 42/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.66s
#    ✅ D₂ = 0.2442 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 45.45s | Total: 31.96 min | Restante: 43.93 min
#
# 📊 Realización 43/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.74s
#    ✅ D₂ = 0.2437 | Media D₂ = 0.2435 ± 0.0005
#    ⏱️  Esta: 46.39s | Total: 32.73 min | Restante: 44.07 min
#
# 📊 Realización 44/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.65s
#    ✅ D₂ = 0.2425 | Media D₂ = 0.2435 ± 0.0006
#    ⏱️  Esta: 45.37s | Total: 33.49 min | Restante: 42.34 min
#
# 📊 Realización 45/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.78s
#    ✅ D₂ = 0.2429 | Media D₂ = 0.2435 ± 0.0006
#    ⏱️  Esta: 45.69s | Total: 34.25 min | Restante: 41.89 min
#    💾 Checkpoint guardado
#
# 📊 Realización 46/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.64s
#    ✅ D₂ = 0.2432 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 46.06s | Total: 35.02 min | Restante: 41.45 min
#
# 📊 Realización 47/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.77s
#    ✅ D₂ = 0.2432 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.63s | Total: 35.78 min | Restante: 40.31 min
#
# 📊 Realización 48/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
# ...
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.68s
#    ✅ D₂ = 0.2436 | Media D₂ = 0.2434 ± 0.0006
#    ⏱️  Esta: 46.13s | Total: 64.76 min | Restante: 11.53 min
#    💾 Checkpoint guardado
#
# 📊 Realización 86/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.68s
#    ✅ D₂ = 0.2435 | Media D₂ = 0.2434 ± 0.0006
#    ⏱️  Esta: 45.40s | Total: 65.52 min | Restante: 10.59 min
#
# 📊 Realización 87/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.87s
#    ✅ D₂ = 0.2433 | Media D₂ = 0.2434 ± 0.0006
#    ⏱️  Esta: 45.83s | Total: 66.29 min | Restante: 9.93 min
#
# 📊 Realización 88/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.61s
#    ✅ D₂ = 0.2432 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.89s | Total: 67.05 min | Restante: 9.18 min
#
# 📊 Realización 89/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.71s
#    ✅ D₂ = 0.2434 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.61s | Total: 67.81 min | Restante: 8.36 min
#
# 📊 Realización 90/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.72s
#    ✅ D₂ = 0.2436 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.80s | Total: 68.57 min | Restante: 7.63 min
#    💾 Checkpoint guardado
#
# 📊 Realización 91/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.66s
#    ✅ D₂ = 0.2441 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.40s | Total: 69.33 min | Restante: 6.81 min
#
# 📊 Realización 92/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.70s
#    ✅ D₂ = 0.2437 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.98s | Total: 70.10 min | Restante: 6.13 min
#
# 📊 Realización 93/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.59s
#    ✅ D₂ = 0.2443 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.39s | Total: 70.85 min | Restante: 5.29 min
#
# 📊 Realización 94/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.77s
#    ✅ D₂ = 0.2439 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.63s | Total: 71.61 min | Restante: 4.56 min
#
# 📊 Realización 95/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.70s
#    ✅ D₂ = 0.2434 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 46.32s | Total: 72.39 min | Restante: 3.86 min
#    💾 Checkpoint guardado
#
# 📊 Realización 96/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.63s
#    ✅ D₂ = 0.2434 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.33s | Total: 73.14 min | Restante: 3.02 min
#
# 📊 Realización 97/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.67s
#    ✅ D₂ = 0.2439 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.54s | Total: 73.90 min | Restante: 2.28 min
#
# 📊 Realización 98/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.71s
#    ✅ D₂ = 0.2429 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 46.03s | Total: 74.67 min | Restante: 1.53 min
#
# 📊 Realización 99/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.74s
#    ✅ D₂ = 0.2433 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.69s | Total: 75.43 min | Restante: 0.76 min
#
# 📊 Realización 100/100
#    Construyendo matriz...
#       Procesadas 50/5000 distancias
#       Procesadas 300/5000 distancias
#       Procesadas 550/5000 distancias
#       Procesadas 800/5000 distancias
#       Procesadas 1050/5000 distancias
#       Procesadas 1300/5000 distancias
#       Procesadas 1550/5000 distancias
#       Procesadas 1800/5000 distancias
#       Procesadas 2050/5000 distancias
#       Procesadas 2300/5000 distancias
#       Procesadas 2550/5000 distancias
#       Procesadas 2800/5000 distancias
#       Procesadas 3050/5000 distancias
#       Procesadas 3300/5000 distancias
#       Procesadas 3550/5000 distancias
#       Procesadas 3800/5000 distancias
#       Procesadas 4050/5000 distancias
#       Procesadas 4300/5000 distancias
#       Procesadas 4550/5000 distancias
#       Procesadas 4800/5000 distancias
#    ✅ Total elementos no-diagonales: 37500000
#    Diagonalizando...
#    ⏱️  Diagonalización: 30.78s
#    ✅ D₂ = 0.2422 | Media D₂ = 0.2434 ± 0.0005
#    ⏱️  Esta: 45.61s | Total: 76.19 min | Restante: 0.00 min
#    💾 Checkpoint guardado

# %%
# =============================================================================
# CELDA 8: VALIDACIÓN TERMODINÁMICA EXIGIDA POR PRL (usando checkpoint existente)
# =============================================================================
# Esta celda carga el checkpoint de 100 realizaciones y genera TODOS los
# estadísticos requeridos por los revisores: D₂, γ, intervalos de confianza,
# test de Shapiro-Wilk, bootstrap, etc.
# =============================================================================

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress, shapiro
from scipy.interpolate import UnivariateSpline
from sklearn.utils import resample
import os
import warnings
warnings.filterwarnings('ignore')

# -----------------------------------------------------------------------------
# CONFIGURACIÓN
# -----------------------------------------------------------------------------
print("="*70)
print("🔬 VALIDACIÓN TERMODINÁMICA EXIGIDA POR PRL")
print("="*70)

# Constantes físicas
T_HEISENBERG = 2 * np.pi
N_SIZE = 15000
M_REALIZATIONS = 100

# Reconstruir t_values (mismo que en el bucle)
t_values = np.logspace(-1.5, np.log10(3*np.pi), 500)

# -----------------------------------------------------------------------------
# CARGAR CHECKPOINT
# -----------------------------------------------------------------------------
checkpoint_file = 'ensemble_checkpoint.npz'

if not os.path.exists(checkpoint_file):
    # Buscar checkpoints alternativos
    import glob
    checkpoints = glob.glob('ensemble_checkpoint*.npz')
    if checkpoints:
        checkpoint_file = sorted(checkpoints)[-1]
        print(f"📦 Usando checkpoint: {checkpoint_file}")
    else:
        raise FileNotFoundError("❌ No se encontró ningún checkpoint. Ejecuta primero el ensamble.")

data = np.load(checkpoint_file)
K_total = data['K_total']
D2_list = data['D2_list']
M_completed = len(D2_list)

print(f"\n📊 Datos cargados:")
print(f"   - Realizaciones completadas: {M_completed}/{M_REALIZATIONS}")
print(f"   - Dimensión fractal D₂: {len(D2_list)} valores")
print(f"   - SFF acumulado: {K_total.shape}")

# -----------------------------------------------------------------------------
# FUNCIONES AUXILIARES
# -----------------------------------------------------------------------------
def detect_dip_robust(t_values, K_values, smooth_factor=0.02):
    """
    Detecta el dip (mínimo) del SFF usando interpolación por splines.
    Retorna t_dip, K_dip.
    """
    log_t = np.log(t_values)
    log_K = np.log(K_values)

    # Crear spline suavizado
    spline = UnivariateSpline(log_t, log_K, s=len(t_values) * smooth_factor)
    log_t_fine = np.linspace(log_t[0], log_t[-1], 1000)
    log_K_fine = spline(log_t_fine)

    idx_dip = np.argmin(log_K_fine)
    t_dip = np.exp(log_t_fine[idx_dip])
    K_dip = np.exp(log_K_fine[idx_dip])

    return t_dip, K_dip

def bootstrap_gamma_ci(log_t, log_K, n_bootstrap=10000):
    """
    Calcula el intervalo de confianza de γ mediante bootstrap
    de los puntos de la rampa.
    """
    boot_gamma = []
    n_points = len(log_t)

    for _ in range(n_bootstrap):
        idx = np.random.choice(n_points, n_points, replace=True)
        log_t_sample = log_t[idx]
        log_K_sample = log_K[idx]

        try:
            slope, _, _, _, _ = linregress(log_t_sample, log_K_sample)
            boot_gamma.append(slope)
        except:
            continue

    boot_gamma = np.array(boot_gamma)
    ci_low, ci_high = np.percentile(boot_gamma, [2.5, 97.5])
    return ci_low, ci_high, boot_gamma

def bootstrap_d2_ci(d2_array, n_bootstrap=10000):
    """
    Calcula el intervalo de confianza de D₂ mediante bootstrap
    de las realizaciones.
    """
    boot_means = []
    n_real = len(d2_array)

    for _ in range(n_bootstrap):
        idx = np.random.choice(n_real, n_real, replace=True)
        boot_sample = d2_array[idx]
        boot_means.append(np.mean(boot_sample))

    boot_means = np.array(boot_means)
    ci_low, ci_high = np.percentile(boot_means, [2.5, 97.5])
    return ci_low, ci_high, boot_means

# -----------------------------------------------------------------------------
# ANÁLISIS DE DIMENSIÓN FRACTAL D₂
# -----------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🔷 ANÁLISIS DE DIMENSIÓN FRACTAL D₂")
print(f"{'='*70}")

d2_mean = np.mean(D2_list)
d2_median = np.median(D2_list)
d2_std = np.std(D2_list)
d2_sem = d2_std / np.sqrt(len(D2_list))
d2_min = np.min(D2_list)
d2_max = np.max(D2_list)

# Intervalo de confianza por bootstrap
d2_ci_low, d2_ci_high, d2_boot = bootstrap_d2_ci(D2_list)

# Test de normalidad (Shapiro-Wilk)
shapiro_stat, shapiro_p = shapiro(D2_list)

print(f"\n📊 Estadísticos descriptivos:")
print(f"   Media: {d2_mean:.6f}")
print(f"   Mediana: {d2_median:.6f}")
print(f"   Desviación estándar: {d2_std:.6f}")
print(f"   Error estándar de la media: {d2_sem:.6f}")
print(f"   IC 95% (bootstrap): [{d2_ci_low:.6f}, {d2_ci_high:.6f}]")
print(f"   Rango: [{d2_min:.6f}, {d2_max:.6f}]")
print(f"\n📋 Test de normalidad (Shapiro-Wilk):")
print(f"   Estadístico W = {shapiro_stat:.4f}")
print(f"   p-valor = {shapiro_p:.4f}")
print(f"   Distribución {'normal' if shapiro_p > 0.05 else 'no normal'} (α=0.05)")

# -----------------------------------------------------------------------------
# ANÁLISIS DEL SFF Y RAMPA
# -----------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🔷 ANÁLISIS DEL SPECTRAL FORM FACTOR")
print(f"{'='*70}")

# SFF promedio
K_avg = K_total / M_completed

# Detección del dip
t_dip, K_dip = detect_dip_robust(t_values, K_avg)
print(f"\n📐 Parámetros detectados:")
print(f"   t_dip = {t_dip:.4f}")
print(f"   K_dip = {K_dip:.6f}")

# Definir rango de la rampa (criterio estándar en literatura NEE)
t_min_ramp = max(1.2 * t_dip, 0.5)
t_max_ramp = 0.7 * T_HEISENBERG  # ~4.4
ramp_mask = (t_values > t_min_ramp) & (t_values < t_max_ramp)
n_ramp_points = np.sum(ramp_mask)

print(f"   Rango rampa: [{t_min_ramp:.4f}, {t_max_ramp:.4f}]")
print(f"   Puntos en rampa: {n_ramp_points}")

if n_ramp_points < 10:
    print("⚠️  Pocos puntos en la rampa. Usando rango alternativo...")
    ramp_mask = (t_values > t_dip) & (t_values < 0.8 * T_HEISENBERG)
    n_ramp_points = np.sum(ramp_mask)
    t_min_ramp = t_values[ramp_mask][0]
    t_max_ramp = t_values[ramp_mask][-1]
    print(f"   Nuevo rango: [{t_min_ramp:.4f}, {t_max_ramp:.4f}]")
    print(f"   Nuevos puntos: {n_ramp_points}")

# Extraer datos de la rampa
t_ramp = t_values[ramp_mask]
K_ramp = K_avg[ramp_mask]
log_t_ramp = np.log(t_ramp)
log_K_ramp = np.log(K_ramp)

# -----------------------------------------------------------------------------
# AJUSTE DE LA RAMPA (γ)
# -----------------------------------------------------------------------------
slope, intercept, r_value, p_value, std_err = linregress(log_t_ramp, log_K_ramp)
gamma = slope
r_squared = r_value**2

# Bootstrap para intervalo de confianza
gamma_ci_low, gamma_ci_high, gamma_boot = bootstrap_gamma_ci(log_t_ramp, log_K_ramp, n_bootstrap=10000)
gamma_bootstrap_mean = np.mean(gamma_boot)
gamma_bootstrap_std = np.std(gamma_boot)

print(f"\n📈 AJUSTE DE LA RAMPA (γ):")
print(f"   γ = {gamma:.6f} ± {std_err:.6f} (error estándar)")
print(f"   Bootstrap: γ = {gamma_bootstrap_mean:.6f} ± {gamma_bootstrap_std:.6f}")
print(f"   IC 95% (bootstrap): [{gamma_ci_low:.6f}, {gamma_ci_high:.6f}]")
print(f"   R² = {r_squared:.6f}")
print(f"   p-valor = {p_value:.6e}")

# -----------------------------------------------------------------------------
# ANOMALÍA η = γ - D₂
# -----------------------------------------------------------------------------
eta = gamma - d2_mean
eta_error = np.sqrt(std_err**2 + d2_sem**2)

print(f"\n🔷 ANOMALÍA η = γ - D₂:")
print(f"   η = {eta:.6f} ± {eta_error:.6f}")
print(f"   Interpretación: Desviación de ergodicidad completa")

# -----------------------------------------------------------------------------
# VERIFICACIÓN DE FASE NEE
# -----------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🔷 VERIFICACIÓN DE FASE NEE")
print(f"{'='*70}")

criterios = {
    'D₂ < 0.5': d2_mean < 0.5,
    'γ < 0.8': gamma < 0.8,
    'η > 0.05': eta > 0.05,
    'R² > 0.8': r_squared > 0.8
}

for criterio, cumplido in criterios.items():
    print(f"   {criterio}: {'✅' if cumplido else '❌'}")

if all(criterios.values()):
    print("\n✅ **CONCLUSIÓN: FASE NEE CONFIRMADA**")
    print("   El sistema presenta todas las características de una fase extendida no-ergódica:")
    print("   - Dimensión fractal reducida (D₂ < 0.5)")
    print("   - Rampa subdifusiva (γ < 0.8)")
    print("   - Anomalía positiva (η > 0.05)")
    print("   - Ajuste de alta calidad (R² > 0.8)")
else:
    print("\n⚠️ **CONCLUSIÓN: FASE NEE NO CONFIRMADA**")
    print("   Algunos criterios no se cumplen. Verificar parámetros.")

# -----------------------------------------------------------------------------
# RESUMEN PARA EL ARTÍCULO (formato LaTeX)
# -----------------------------------------------------------------------------
print(f"\n{'='*70}")
print("📋 RESUMEN PARA EL ARTÍCULO (formato LaTeX)")
print(f"{'='*70}")

latex_summary = f"""
\\begin{{table}}[h]
\\caption{{Resultados de la validación NEE para el Hamiltoniano $\\hat{{H}}_{{\\text{{mod}}}}$ (N={N_SIZE}, M={M_completed})}}
\\label{{tab:resultados_finales}}
\\begin{{tabular}}{{lcc}}
\\hline
\\textbf{{Magnitud}} & \\textbf{{Valor}} & \\textbf{{Interpretación}} \\\\
\\hline
$D_2$ (dimensión fractal) & ${d2_mean:.4f} \\pm {d2_sem:.4f}$ & Soporte multifractal reducido \\\\
$\\gamma$ (exponente de rampa) & ${gamma:.4f} \\pm {std_err:.4f}$ & Difusión subdifusiva \\\\
$\\eta = \\gamma - D_2$ & ${eta:.4f} \\pm {eta_error:.4f}$ & Anomalía de retrodispersión \\\\
$R^2$ del ajuste & ${r_squared:.4f}$ & Calidad del ajuste \\\\
$t_{{\\text{{dip}}}}$ & ${t_dip:.4f}$ & Fin del régimen no universal \\\\
\\hline
\\end{{tabular}}
\\end{{table}}
"""

print(latex_summary)

# -----------------------------------------------------------------------------
# GUARDAR RESULTADOS
# -----------------------------------------------------------------------------
resultados = {
    'D2': {
        'mean': d2_mean,
        'std': d2_std,
        'sem': d2_sem,
        'ci_low': d2_ci_low,
        'ci_high': d2_ci_high,
        'list': D2_list.tolist()
    },
    'gamma': {
        'value': gamma,
        'std_err': std_err,
        'bootstrap_mean': gamma_bootstrap_mean,
        'bootstrap_std': gamma_bootstrap_std,
        'ci_low': gamma_ci_low,
        'ci_high': gamma_ci_high,
        'r_squared': r_squared
    },
    'eta': {
        'value': eta,
        'error': eta_error
    },
    'parameters': {
        'N': N_SIZE,
        'M': M_completed,
        't_dip': t_dip,
        't_H': T_HEISENBERG,
        't_min_ramp': t_min_ramp,
        't_max_ramp': t_max_ramp
    }
}

np.savez('resultados_validacion_prl.npz', **resultados)
print(f"\n✅ Resultados guardados en 'resultados_validacion_prl.npz'")

# -----------------------------------------------------------------------------
# GRÁFICA DE VERIFICACIÓN (opcional, para visualizar el ajuste)
# -----------------------------------------------------------------------------
plt.figure(figsize=(10,6))
plt.loglog(t_values, K_avg, 'b-', linewidth=2, label='SFF promedio')
plt.loglog(t_ramp, np.exp(intercept) * t_ramp**gamma, 'r--', linewidth=2,
           label=f'Ajuste: γ={gamma:.3f}')
plt.axvline(t_dip, color='orange', ls='--', label=f'Dip t={t_dip:.3f}')
plt.axvline(T_HEISENBERG, color='k', ls=':', label='t_H')
plt.axvline(t_min_ramp, color='gray', ls='--', alpha=0.5)
plt.axvline(t_max_ramp, color='gray', ls='--', alpha=0.5, label='Rango rampa')
plt.xlabel('t')
plt.ylabel('K(t)')
plt.title(f'Validación NEE: γ={gamma:.3f}, D₂={d2_mean:.3f}')
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig('validacion_rampa.png', dpi=150)
plt.show()

print(f"\n✅ Gráfico guardado como 'validacion_rampa.png'")
print(f"\n{'='*70}")
print("🎯 VALIDACIÓN COMPLETADA CON ÉXITO")
print(f"{'='*70}")
# Out:
# ======================================================================
# 🔬 VALIDACIÓN TERMODINÁMICA EXIGIDA POR PRL
# ======================================================================
#
# 📊 Datos cargados:
#    - Realizaciones completadas: 100/100
#    - Dimensión fractal D₂: 100 valores
#    - SFF acumulado: (500,)
#
# ======================================================================
# 🔷 ANÁLISIS DE DIMENSIÓN FRACTAL D₂
# ======================================================================
#
# 📊 Estadísticos descriptivos:
#    Media: 0.243383
#    Mediana: 0.243405
#    Desviación estándar: 0.000550
#    Error estándar de la media: 0.000055
#    IC 95% (bootstrap): [0.243277, 0.243490]
#    Rango: [0.242001, 0.244638]
#
# 📋 Test de normalidad (Shapiro-Wilk):
#    Estadístico W = 0.9917
#    p-valor = 0.7960
#    Distribución normal (α=0.05)
#
# ======================================================================
# 🔷 ANÁLISIS DEL SPECTRAL FORM FACTOR
# ======================================================================
#
# 📐 Parámetros detectados:
#    t_dip = 0.0331
#    K_dip = 0.003178
#    Rango rampa: [0.5000, 4.3982]
#    Puntos en rampa: 191
#
# 📈 AJUSTE DE LA RAMPA (γ):
#    γ = 0.608088 ± 0.015946 (error estándar)
#    Bootstrap: γ = 0.607902 ± 0.017391
#    IC 95% (bootstrap): [0.573607, 0.642198]
#    R² = 0.884983
#    p-valor = 1.075344e-90
#
# 🔷 ANOMALÍA η = γ - D₂:
#    η = 0.364705 ± 0.015946
#    Interpretación: Desviación de ergodicidad completa
#
# ======================================================================
# 🔷 VERIFICACIÓN DE FASE NEE
# ======================================================================
#    D₂ < 0.5: ✅
#    γ < 0.8: ✅
#    η > 0.05: ✅
#    R² > 0.8: ✅
#
# ✅ **CONCLUSIÓN: FASE NEE CONFIRMADA**
#    El sistema presenta todas las características de una fase extendida no-ergódica:
#    - Dimensión fractal reducida (D₂ < 0.5)
#    - Rampa subdifusiva (γ < 0.8)
#    - Anomalía positiva (η > 0.05)
#    - Ajuste de alta calidad (R² > 0.8)
#
# ======================================================================
# 📋 RESUMEN PARA EL ARTÍCULO (formato LaTeX)
# ======================================================================
#
# \begin{table}[h]
# \caption{Resultados de la validación NEE para el Hamiltoniano $\hat{H}_{\text{mod}}$ (N=15000, M=100)}
# \label{tab:resultados_finales}
# \begin{tabular}{lcc}
# \hline
# \textbf{Magnitud} & \textbf{Valor} & \textbf{Interpretación} \\
# \hline
# $D_2$ (dimensión fractal) & $0.2434 \pm 0.0001$ & Soporte multifractal reducido \\
# $\gamma$ (exponente de rampa) & $0.6081 \pm 0.0159$ & Difusión subdifusiva \\
# $\eta = \gamma - D_2$ & $0.3647 \pm 0.0159$ & Anomalía de retrodispersión \\
# $R^2$ del ajuste & $0.8850$ & Calidad del ajuste \\
# $t_{\text{dip}}$ & $0.0331$ & Fin del régimen no universal \\
# \hline
# \end{tabular}
# \end{table}
#
#
# ✅ Resultados guardados en 'resultados_validacion_prl.npz'
# ✅ Gráfico guardado como 'validacion_rampa.png'
#
# ======================================================================
# 🎯 VALIDACIÓN COMPLETADA CON ÉXITO
# ======================================================================

# %%
# ==============================================================================
# CELDA FINAL: ANÁLISIS COMPLETO PARA PRL (CON INSET EXIGIDO POR REVISORES)
# ==============================================================================
# Ejecutar después de completar las 100 realizaciones y la Celda 8
# ==============================================================================

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress, norm
from scipy.interpolate import UnivariateSpline
import json
from datetime import datetime
import os
import glob

# ------------------------------------------------------------------------------
# CONFIGURACIÓN ESTÉTICA PRL
# ------------------------------------------------------------------------------
plt.style.use('seaborn-v0_8-paper')
plt.rcParams.update({
    'font.family': 'serif',
    'font.size': 11,
    'axes.labelsize': 12,
    'axes.titlesize': 12,
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'figure.dpi': 300,
    'text.usetex': False
})

# ------------------------------------------------------------------------------
# CONSTANTES
# ------------------------------------------------------------------------------
EPSILON_CRITICAL = np.pi * np.sqrt(2)
NU_EXPONENT = 0.75
T_HEISENBERG = 2 * np.pi
PHASE_SHIFT = 7/8
N_SIZE = 15000
M_REALIZATIONS = 100

# ------------------------------------------------------------------------------
# CARGAR RESULTADOS DEL CHECKPOINT FINAL
# ------------------------------------------------------------------------------
print("="*70)
print("📊 ANÁLISIS FINAL: ENSAMBLE ℤ/6ℤ (N=15000, M=100)")
print("="*70)

# Cargar el último checkpoint
checkpoint_file = 'ensemble_checkpoint.npz'
if not os.path.exists(checkpoint_file):
    checkpoints = glob.glob('ensemble_checkpoint*.npz')
    if checkpoints:
        checkpoint_file = sorted(checkpoints)[-1]
        print(f"📦 Usando checkpoint: {checkpoint_file}")
    else:
        raise FileNotFoundError("No se encontró ningún checkpoint")

data = np.load(checkpoint_file)
K_total = data['K_total']
D2_list = data['D2_list'].tolist()
M_completed = len(D2_list)

print(f"\n📈 Realizaciones completadas: {M_completed}/{M_REALIZATIONS}")

# ------------------------------------------------------------------------------
# ANÁLISIS DE D₂ (DIMENSIÓN FRACTAL)
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🔷 ANÁLISIS DE DIMENSIÓN FRACTAL D₂")
print(f"{'='*70}")

D2_mean = np.mean(D2_list)
D2_std = np.std(D2_list)
D2_median = np.median(D2_list)
D2_ci_low, D2_ci_high = np.percentile(D2_list, [2.5, 97.5])
D2_sem = D2_std / np.sqrt(len(D2_list))

print(f"\n📊 Estadísticos descriptivos:")
print(f"   Media: {D2_mean:.6f}")
print(f"   Mediana: {D2_median:.6f}")
print(f"   Desviación estándar: {D2_std:.6f}")
print(f"   Error estándar de la media: {D2_sem:.6f}")
print(f"   IC 95%: [{D2_ci_low:.6f}, {D2_ci_high:.6f}]")

from scipy.stats import shapiro
shapiro_stat, shapiro_p = shapiro(D2_list)
print(f"\n📋 Test de normalidad (Shapiro-Wilk):")
print(f"   Estadístico W = {shapiro_stat:.4f}")
print(f"   p-valor = {shapiro_p:.4f}")
print(f"   Distribución {'normal' if shapiro_p > 0.05 else 'no normal'} (α=0.05)")

# ------------------------------------------------------------------------------
# ANÁLISIS DEL SFF Y RAMPA
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🔷 ANÁLISIS DEL SPECTRAL FORM FACTOR")
print(f"{'='*70}")

t_values = np.logspace(-1.5, np.log10(3*np.pi), 500)
K_avg = K_total / M_completed

# ------------------------------------------------------------------------------
# DETECCIÓN AUTOMÁTICA DEL DIP Y RANGO ÓPTIMO
# ------------------------------------------------------------------------------
def detect_optimal_ramp_range(t_values, K_values):
    log_t = np.log(t_values)
    log_K = np.log(K_values)
    spline = UnivariateSpline(log_t, log_K, s=len(t_values)*0.02)
    log_t_fine = np.linspace(log_t[0], log_t[-1], 1000)
    log_K_fine = spline(log_t_fine)

    idx_dip = np.argmin(log_K_fine)
    t_dip = np.exp(log_t_fine[idx_dip])
    K_dip = np.exp(log_K_fine[idx_dip])

    first_deriv = np.gradient(log_K_fine, log_t_fine)
    second_deriv = np.gradient(first_deriv, log_t_fine)
    curvature = np.abs(second_deriv)
    curvature = curvature / np.max(curvature)

    post_dip_indices = np.where(log_t_fine > log_t_fine[idx_dip])[0]

    if len(post_dip_indices) > 0:
        low_curvature = []
        current_region = []
        for idx in post_dip_indices:
            if curvature[idx] < 0.2:
                current_region.append(idx)
            else:
                if len(current_region) > 10:
                    low_curvature.append(current_region)
                current_region = []
        if len(current_region) > 10:
            low_curvature.append(current_region)

        if low_curvature:
            longest_region = max(low_curvature, key=len)
            idx_start = longest_region[0]
            idx_end = longest_region[-1]
            t_min_ramp = np.exp(log_t_fine[idx_start])
            t_max_ramp = np.exp(log_t_fine[idx_end])
        else:
            t_min_ramp = max(1.2 * t_dip, 0.5)
            t_max_ramp = 0.7 * T_HEISENBERG
    else:
        t_min_ramp = max(1.2 * t_dip, 0.5)
        t_max_ramp = 0.7 * T_HEISENBERG

    ramp_mask = (t_values > t_min_ramp) & (t_values < t_max_ramp)
    return t_dip, K_dip, ramp_mask, {'t_min': t_min_ramp, 't_max': t_max_ramp}

t_dip, K_dip, ramp_mask, ramp_info = detect_optimal_ramp_range(t_values, K_avg)

print(f"\n📐 Parámetros detectados:")
print(f"   t_dip = {t_dip:.4f}")
print(f"   K_dip = {K_dip:.6f}")
print(f"   Rango rampa: [{ramp_info['t_min']:.4f}, {ramp_info['t_max']:.4f}]")
print(f"   Puntos en rampa: {np.sum(ramp_mask)}")

# ------------------------------------------------------------------------------
# AJUSTE DE LA RAMPA CON BOOTSTRAP
# ------------------------------------------------------------------------------
log_t_ramp = np.log(t_values[ramp_mask])
log_K_ramp = np.log(K_avg[ramp_mask])

slope, intercept, r_value, p_value, std_err = linregress(log_t_ramp, log_K_ramp)
gamma = slope
gamma_error = std_err
r_squared = r_value**2

n_bootstrap = 10000
bootstrap_slopes = []
for _ in range(n_bootstrap):
    indices = np.random.choice(len(log_t_ramp), len(log_t_ramp), replace=True)
    log_t_sample = log_t_ramp[indices]
    log_K_sample = log_K_ramp[indices]
    try:
        s, _, _, _, _ = linregress(log_t_sample, log_K_sample)
        bootstrap_slopes.append(s)
    except:
        continue
bootstrap_slopes = np.array(bootstrap_slopes)
gamma_ci_low, gamma_ci_high = np.percentile(bootstrap_slopes, [2.5, 97.5])

print(f"\n📈 Ajuste de la rampa (γ):")
print(f"   γ = {gamma:.6f} ± {gamma_error:.6f}")
print(f"   Bootstrap: γ = {np.mean(bootstrap_slopes):.6f} ± {np.std(bootstrap_slopes):.6f}")
print(f"   IC 95%: [{gamma_ci_low:.6f}, {gamma_ci_high:.6f}]")
print(f"   R² = {r_squared:.6f}")

# ------------------------------------------------------------------------------
# ANOMALÍA η = γ - D₂
# ------------------------------------------------------------------------------
eta = gamma - D2_mean
eta_error = np.sqrt(gamma_error**2 + D2_sem**2)
print(f"\n🔷 ANOMALÍA η = γ - D₂: {eta:.6f} ± {eta_error:.6f}")

# ------------------------------------------------------------------------------
# VERIFICACIÓN DE FASE NEE
# ------------------------------------------------------------------------------
criterios = {
    'D₂ < 0.5': D2_mean < 0.5,
    'γ < 0.8': gamma < 0.8,
    'η > 0.05': eta > 0.05,
    'R² > 0.8': r_squared > 0.8
}
print(f"\n{'='*70}")
print("🔷 VERIFICACIÓN DE FASE NEE")
for k, v in criterios.items():
    print(f"   {k}: {'✅' if v else '❌'}")
if all(criterios.values()):
    print("\n✅ **CONCLUSIÓN: FASE NEE CONFIRMADA**")
else:
    print("\n⚠️ **CONCLUSIÓN: FASE NEE NO CONFIRMADA**")

# ------------------------------------------------------------------------------
# GRÁFICA PRL COMPLETA (4 PANELES) CON INSET EN PANEL (a)
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🎨 GENERANDO FIGURA PRL CON INSET")
print(f"{'='*70}")

fig = plt.figure(figsize=(16, 12))

# ------------------------------------------------------------------------------
# PANEL 1: SFF CON RAMPA E INSET
# ------------------------------------------------------------------------------
ax1 = plt.subplot(2, 2, 1)

# SFF promedio
ax1.loglog(t_values, K_avg, 'b-', linewidth=2, label=f'SFF promedio (M={M_completed})', zorder=5)

# Rampa GUE teórica
t_gue = np.linspace(t_values[0], T_HEISENBERG, 200)
K_gue = t_gue / T_HEISENBERG * K_dip * (T_HEISENBERG / t_dip)
ax1.loglog(t_gue, K_gue, 'k--', alpha=0.5, linewidth=1.5, label='GUE teórico (γ=1)', zorder=4)

# Ajuste NEE
t_fit = t_values[ramp_mask]
K_fit = np.exp(intercept) * t_fit**gamma
ax1.loglog(t_fit, K_fit, 'r-', linewidth=2.5,
           label=rf'NEE: γ = {gamma:.3f}±{gamma_error:.3f}', zorder=6)

# Líneas de referencia
ax1.axvline(x=t_dip, color='orange', linestyle='--', alpha=0.7, linewidth=1.5,
            label=f'Dip t={t_dip:.3f}', zorder=3)
ax1.axvline(x=T_HEISENBERG, color='red', linestyle=':', linewidth=2,
            label=r'$t_H = 2\pi$', zorder=3)
ax1.axhline(y=1.0, color='green', linestyle=':', alpha=0.5, linewidth=1.5, zorder=3)

# Sombreado del rango de la rampa
ax1.axvspan(ramp_info['t_min'], ramp_info['t_max'], alpha=0.1, color='yellow', label='Rango rampa')

ax1.set_xlabel('Tiempo $t$', fontsize=12)
ax1.set_ylabel('$\\langle K(t) \\rangle$', fontsize=12)
ax1.set_title('(a) Spectral Form Factor: Rampa Fraccionaria', fontsize=12, fontweight='bold')
ax1.legend(loc='lower right', fontsize=9, framealpha=0.9)
ax1.grid(True, alpha=0.3, which='both')
ax1.set_xlim([t_values[0], t_values[-1]])
ax1.set_ylim([np.min(K_avg)*0.5, 2.0])

# ------------------- INSET (zoom en la rampa) -------------------
left, bottom, width, height = [0.58, 0.55, 0.25, 0.25]  # Esquina superior derecha
ax_inset = fig.add_axes([left, bottom, width, height])

# Datos en el inset
ax_inset.loglog(t_fit, K_fit, 'r-', linewidth=2, label=f'Ajuste γ={gamma:.3f}')
ax_inset.loglog(t_fit, np.exp(intercept) * t_fit**1.0, 'k--', alpha=0.6, linewidth=1.5, label='γ=1.0')
ax_inset.loglog(t_fit, K_avg[ramp_mask], 'b.', markersize=2, alpha=0.4, label='Datos')

ax_inset.set_xlabel('$t$', fontsize=9)
ax_inset.set_ylabel('$K(t)$', fontsize=9)
ax_inset.set_title('Rampa (zoom)', fontsize=10)
ax_inset.legend(fontsize=7, loc='lower right', framealpha=0.9)
ax_inset.grid(True, alpha=0.3, which='both')
ax_inset.tick_params(labelsize=8)

# ------------------------------------------------------------------------------
# PANEL 2: HISTOGRAMA DE D₂
# ------------------------------------------------------------------------------
ax2 = plt.subplot(2, 2, 2)
n_bins = int(np.sqrt(len(D2_list)) * 2)
ax2.hist(D2_list, bins=n_bins, color='steelblue', edgecolor='black', alpha=0.7, density=True)

x_norm = np.linspace(D2_mean - 4*D2_std, D2_mean + 4*D2_std, 200)
y_norm = norm.pdf(x_norm, D2_mean, D2_std)
ax2.plot(x_norm, y_norm, 'r-', linewidth=2, label='Ajuste normal')

ax2.axvline(x=D2_mean, color='red', linewidth=2, label=f'Media = {D2_mean:.4f}')
ax2.axvline(x=D2_ci_low, color='red', linestyle='--', alpha=0.7, linewidth=1.5)
ax2.axvline(x=D2_ci_high, color='red', linestyle='--', alpha=0.7, linewidth=1.5, label='IC 95%')

ax2.set_xlabel('$D_2$', fontsize=12)
ax2.set_ylabel('Densidad', fontsize=12)
ax2.set_title('(b) Distribución de Dimensión Fractal', fontsize=12, fontweight='bold')
ax2.legend(loc='upper right', fontsize=9)
ax2.grid(True, alpha=0.3)

stats_text = f'μ = {D2_mean:.4f}\nσ = {D2_std:.4f}\nSEM = {D2_sem:.4f}'
ax2.text(0.05, 0.95, stats_text, transform=ax2.transAxes, fontsize=10,
         verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

# ------------------------------------------------------------------------------
# PANEL 3: CONVERGENCIA DE D₂
# ------------------------------------------------------------------------------
ax3 = plt.subplot(2, 2, 3)
cumulative_mean = [np.mean(D2_list[:i+1]) for i in range(len(D2_list))]
cumulative_sem = [np.std(D2_list[:i+1])/np.sqrt(i+1) for i in range(len(D2_list))]
x_vals = range(1, len(D2_list)+1)

ax3.errorbar(x_vals, cumulative_mean, yerr=cumulative_sem, fmt='o-',
             color='darkgreen', markersize=3, capsize=2, linewidth=1.5,
             label='Media acumulada ± SEM')
ax3.axhline(y=D2_mean, color='red', linestyle='--', linewidth=1.5, label=f'Límite: {D2_mean:.4f}')
ax3.fill_between(x_vals,
                  [D2_mean - 2*D2_sem]*len(x_vals),
                  [D2_mean + 2*D2_sem]*len(x_vals),
                  color='red', alpha=0.1, label='IC 95% de la media')

ax3.set_xlabel('Número de realizaciones $M$', fontsize=12)
ax3.set_ylabel('$D_2$ acumulado', fontsize=12)
ax3.set_title('(c) Convergencia de la Dimensión Fractal', fontsize=12, fontweight='bold')
ax3.legend(loc='upper right', fontsize=9)
ax3.grid(True, alpha=0.3)
ax3.set_xlim([1, len(D2_list)])

# ------------------------------------------------------------------------------
# PANEL 4: RESUMEN DE PARÁMETROS
# ------------------------------------------------------------------------------
ax4 = plt.subplot(2, 2, 4)
ax4.axis('off')

info_text = '\n'.join([
    'HAMILTONIANO Z/6Z: RESULTADOS',
    '----------------------------------------',
    'Parámetros fundamentales:',
    f'epsilon_c = π√2 = {EPSILON_CRITICAL:.6f}',
    f'ν = {NU_EXPONENT} (Kato-Rellich bound)',
    'Máscara modular: χ₀⁽⁶⁾(d) ∈ {1,5}',
    f'N = {N_SIZE}, M = {M_completed}',
    '',
    'Resultados experimentales:',
    f'D₂ = {D2_mean:.4f} ± {D2_std:.4f}',
    f'γ  = {gamma:.4f} ± {gamma_error:.4f}',
    f'η  = {eta:.4f} ± {eta_error:.4f}',
    f'R² = {r_squared:.4f}',
    '',
    'Verificación NEE:',
    f'D₂ < 0.5: {"✓" if D2_mean < 0.5 else "✗"}',
    f'γ < 0.8: {"✓" if gamma < 0.8 else "✗"}',
    f'η > 0.05: {"✓" if eta > 0.05 else "✗"}',
    f'R² > 0.8: {"✓" if r_squared > 0.8 else "✗"}',
    '',
    f'FASE NEE: {"CONFIRMADA" if all(criterios.values()) else "NO CONFIRMADA"}'
])

props = dict(boxstyle='round', facecolor='wheat', alpha=0.9, edgecolor='black', linewidth=1)
ax4.text(0.05, 0.95, info_text, transform=ax4.transAxes, fontsize=11,
         verticalalignment='top', horizontalalignment='left',
         fontfamily='monospace', bbox=props)
ax4.set_title('(d) Resumen de Validación', fontsize=12, fontweight='bold')

plt.suptitle(f'Validación NEE: Hamiltoniano ℤ/6ℤ (N={N_SIZE}, M={M_completed})',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('PRL_Figure_Final_con_inset.png', dpi=300, bbox_inches='tight')
plt.show()

print("\n✅ Figura guardada como 'PRL_Figure_Final_con_inset.png'")

# ------------------------------------------------------------------------------
# EXPORTAR RESULTADOS PARA EL ARTÍCULO
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("📋 EXPORTANDO RESULTADOS PARA EL ARTÍCULO")
print(f"{'='*70}")

latex_table = f"""
\\begin{{table}}[h]
\\caption{{Resultados de la validación NEE para el Hamiltoniano $\\hat{{H}}_{{\\text{{mod}}}}$ (N={N_SIZE}, M={M_completed})}}
\\label{{tab:resultados}}
\\begin{{tabular}}{{lcc}}
\\hline
\\textbf{{Magnitud}} & \\textbf{{Valor}} & \\textbf{{Interpretación}} \\\\
\\hline
$D_2$ (dimensión fractal) & ${D2_mean:.4f} \\pm {D2_std:.4f}$ & Soporte multifractal reducido \\\\
$\\gamma$ (exponente de rampa) & ${gamma:.4f} \\pm {gamma_error:.4f}$ & Difusión subdifusiva \\\\
$\\eta = \\gamma - D_2$ & ${eta:.4f} \\pm {eta_error:.4f}$ & Anomalía de retrodispersión \\\\
$R^2$ del ajuste & ${r_squared:.4f}$ & Calidad del ajuste \\\\
$t_{{\\text{{dip}}}}$ & ${t_dip:.4f}$ & Fin del régimen no universal \\\\
\\hline
\\end{{tabular}}
\\end{{table}}
"""

print("\n📄 Tabla LaTeX para el artículo:")
print(latex_table)

results_dict = {
    'D2': {'mean': float(D2_mean), 'std': float(D2_std), 'sem': float(D2_sem),
           'ci_low': float(D2_ci_low), 'ci_high': float(D2_ci_high)},
    'gamma': {'value': float(gamma), 'error': float(gamma_error),
              'ci_low': float(gamma_ci_low), 'ci_high': float(gamma_ci_high),
              'r_squared': float(r_squared)},
    'eta': {'value': float(eta), 'error': float(eta_error)},
    'parameters': {'N': N_SIZE, 'M': M_completed, 't_dip': float(t_dip)},
    'timestamp': datetime.now().isoformat()
}

with open('resultados_prl.json', 'w') as f:
    json.dump(results_dict, f, indent=2)

print("\n✅ Resultados guardados en 'resultados_prl.json'")

# ------------------------------------------------------------------------------
# RESUMEN FINAL
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🎯 RESUMEN FINAL PARA PRL")
print(f"{'='*70}")
print(f"""
📊 **RESULTADOS DEFINITIVOS**

Dimensión fractal:        D₂ = {D2_mean:.4f} ± {D2_std:.4f}
Exponente de rampa:       γ  = {gamma:.4f} ± {gamma_error:.4f}
Anomalía:                 η  = {eta:.4f} ± {eta_error:.4f}
Calidad del ajuste:       R² = {r_squared:.4f}

🔬 **VERIFICACIÓN DE FASE NEE: {'✅ CONFIRMADA' if all(criterios.values()) else '⚠️ NO CONFIRMADA'}**

📁 Archivos generados:
   - PRL_Figure_Final_con_inset.png (figura principal con inset)
   - resultados_prl.json (datos numéricos)
   - Tabla LaTeX (para el artículo)

⏱️  Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
{'='*70}
""")
# Out:
# ======================================================================
# 📊 ANÁLISIS FINAL: ENSAMBLE ℤ/6ℤ (N=15000, M=100)
# ======================================================================
#
# 📈 Realizaciones completadas: 100/100
#
# ======================================================================
# 🔷 ANÁLISIS DE DIMENSIÓN FRACTAL D₂
# ======================================================================
#
# 📊 Estadísticos descriptivos:
#    Media: 0.243383
#    Mediana: 0.243405
#    Desviación estándar: 0.000550
#    Error estándar de la media: 0.000055
#    IC 95%: [0.242301, 0.244515]
#
# 📋 Test de normalidad (Shapiro-Wilk):
#    Estadístico W = 0.9917
#    p-valor = 0.7960
#    Distribución normal (α=0.05)
#
# ======================================================================
# 🔷 ANÁLISIS DEL SPECTRAL FORM FACTOR
# ======================================================================
#
# 📐 Parámetros detectados:
#    t_dip = 0.0331
#    K_dip = 0.003178
#    Rango rampa: [0.0671, 9.4248]
#    Puntos en rampa: 434
#
# 📈 Ajuste de la rampa (γ):
#    γ = 0.608631 ± 0.010291
#    Bootstrap: γ = 0.608134 ± 0.012653
#    IC 95%: [0.583503, 0.632753]
#    R² = 0.890063
#
# 🔷 ANOMALÍA η = γ - D₂: 0.365248 ± 0.010292
#
# ======================================================================
# 🔷 VERIFICACIÓN DE FASE NEE
#    D₂ < 0.5: ✅
#    γ < 0.8: ✅
#    η > 0.05: ✅
#    R² > 0.8: ✅
#
# ✅ **CONCLUSIÓN: FASE NEE CONFIRMADA**
#
# ======================================================================
# 🎨 GENERANDO FIGURA PRL CON INSET
# ======================================================================
# ✅ Figura guardada como 'PRL_Figure_Final_con_inset.png'
#
# ======================================================================
# 📋 EXPORTANDO RESULTADOS PARA EL ARTÍCULO
# ======================================================================
#
# 📄 Tabla LaTeX para el artículo:
#
# \begin{table}[h]
# \caption{Resultados de la validación NEE para el Hamiltoniano $\hat{H}_{\text{mod}}$ (N=15000, M=100)}
# \label{tab:resultados}
# \begin{tabular}{lcc}
# \hline
# \textbf{Magnitud} & \textbf{Valor} & \textbf{Interpretación} \\
# \hline
# $D_2$ (dimensión fractal) & $0.2434 \pm 0.0005$ & Soporte multifractal reducido \\
# $\gamma$ (exponente de rampa) & $0.6086 \pm 0.0103$ & Difusión subdifusiva \\
# $\eta = \gamma - D_2$ & $0.3652 \pm 0.0103$ & Anomalía de retrodispersión \\
# $R^2$ del ajuste & $0.8901$ & Calidad del ajuste \\
# $t_{\text{dip}}$ & $0.0331$ & Fin del régimen no universal \\
# \hline
# \end{tabular}
# \end{table}
#
#
# ✅ Resultados guardados en 'resultados_prl.json'
#
# ======================================================================
# 🎯 RESUMEN FINAL PARA PRL
# ======================================================================
#
# 📊 **RESULTADOS DEFINITIVOS**
#
# Dimensión fractal:        D₂ = 0.2434 ± 0.0005
# Exponente de rampa:       γ  = 0.6086 ± 0.0103
# Anomalía:                 η  = 0.3652 ± 0.0103
# Calidad del ajuste:       R² = 0.8901
#
# 🔬 **VERIFICACIÓN DE FASE NEE: ✅ CONFIRMADA**
#
# 📁 Archivos generados:
#    - PRL_Figure_Final_con_inset.png (figura principal con inset)
#    - resultados_prl.json (datos numéricos)
#    - Tabla LaTeX (para el artículo)
#
# ⏱️  Timestamp: 2026-03-09 19:10:55
# ======================================================================

# %%
# ------------------------------------------------------------------------------
# CELDA 8: ANÁLISIS FINAL Y GRÁFICAS
# ------------------------------------------------------------------------------
print("\n" + "="*70)
print("📈 ANÁLISIS FINAL")
print("="*70)

# Detectar dip y rampa
t_dip, K_dip, ramp_mask = detect_ramp_parameters(t_values, K_avg)

# Ajuste de la rampa
log_t = np.log(t_values[ramp_mask])
log_K = np.log(K_avg[ramp_mask])
slope, intercept, r_value, p_value, std_err = linregress(log_t, log_K)
gamma = slope
eta = gamma - D2_mean

print(f"\n🔷 DIMENSIÓN FRACTAL D₂:")
print(f"   Media: {D2_mean:.6f}")
print(f"   Desviación: {D2_std:.6f}")
print(f"   IC 95%: [{np.percentile(D2_list, 2.5):.6f}, {np.percentile(D2_list, 97.5):.6f}]")

print(f"\n🔷 PARÁMETROS DE LA RAMPA:")
print(f"   t_dip = {t_dip:.4f}")
print(f"   Rango rampa: [{t_values[ramp_mask][0]:.4f}, {t_values[ramp_mask][-1]:.4f}]")
print(f"   γ = {gamma:.6f} ± {std_err:.6f}")
print(f"   R² = {r_value**2:.6f}")

print(f"\n🔷 ANOMALÍA η = γ - D₂:")
print(f"   η = {eta:.6f}")

print(f"\n🔷 VERIFICACIÓN FASE NEE:")
if D2_mean < 0.5 and gamma < 0.8 and eta > 0.05:
    print("   ✅ CONFIRMADA: Fase Extendida No-Ergódica (NEE)")
else:
    print("   ⚠️  NO CONFIRMADA: Verificar parámetros")
# Out:
# ======================================================================
# 📈 ANÁLISIS FINAL
# ======================================================================
#
# 🔷 DIMENSIÓN FRACTAL D₂:
#    Media: 0.243383
#    Desviación: 0.000550
#    IC 95%: [0.242301, 0.244515]
#
# 🔷 PARÁMETROS DE LA RAMPA:
#    t_dip = 0.0331
#    Rango rampa: [0.0672, 9.4248]
#    γ = 0.608631 ± 0.010291
#    R² = 0.890063
#
# 🔷 ANOMALÍA η = γ - D₂:
#    η = 0.365248
#
# 🔷 VERIFICACIÓN FASE NEE:
#    ✅ CONFIRMADA: Fase Extendida No-Ergódica (NEE)

# %%
# ==============================================================================
# CELDA FINAL: ANÁLISIS COMPLETO PARA PRL
# ==============================================================================
# Ejecutar después de completar las 100 realizaciones
# ==============================================================================

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress, norm
from scipy.interpolate import UnivariateSpline
import json
from datetime import datetime

# ------------------------------------------------------------------------------
# CONFIGURACIÓN ESTÉTICA PRL
# ------------------------------------------------------------------------------
plt.style.use('seaborn-v0_8-paper')
plt.rcParams.update({
    'font.family': 'serif',
    'font.size': 11,
    'axes.labelsize': 12,
    'axes.titlesize': 12,
    'legend.fontsize': 10,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'figure.dpi': 300,
    'text.usetex': False
})

# ------------------------------------------------------------------------------
# CONSTANTES
# ------------------------------------------------------------------------------
EPSILON_CRITICAL = np.pi * np.sqrt(2)
NU_EXPONENT = 0.75
T_HEISENBERG = 2 * np.pi
PHASE_SHIFT = 7/8
N_SIZE = 15000
M_REALIZATIONS = 100

# ------------------------------------------------------------------------------
# CARGAR RESULTADOS DEL CHECKPOINT FINAL
# ------------------------------------------------------------------------------
print("="*70)
print("📊 ANÁLISIS FINAL: ENSAMBLE ℤ/6ℤ (N=15000, M=100)")
print("="*70)

# Cargar el último checkpoint
checkpoint_file = 'ensemble_checkpoint.npz'
if not os.path.exists(checkpoint_file):
    # Buscar checkpoints alternativos
    import glob
    checkpoints = glob.glob('ensemble_checkpoint*.npz')
    if checkpoints:
        checkpoint_file = sorted(checkpoints)[-1]
        print(f"📦 Usando checkpoint: {checkpoint_file}")
    else:
        raise FileNotFoundError("No se encontró ningún checkpoint")

data = np.load(checkpoint_file)
K_total = data['K_total']
D2_list = data['D2_list'].tolist()
M_completed = len(D2_list)

print(f"\n📈 Realizaciones completadas: {M_completed}/{M_REALIZATIONS}")

if M_completed < M_REALIZATIONS:
    print(f"⚠️  ADVERTENCIA: Ensamble incompleto ({M_completed} realizaciones)")
    print(f"   Los resultados son preliminares")

# ------------------------------------------------------------------------------
# ANÁLISIS DE D₂ (DIMENSIÓN FRACTAL)
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🔷 ANÁLISIS DE DIMENSIÓN FRACTAL D₂")
print(f"{'='*70}")

D2_mean = np.mean(D2_list)
D2_std = np.std(D2_list)
D2_median = np.median(D2_list)
D2_ci_low, D2_ci_high = np.percentile(D2_list, [2.5, 97.5])
D2_sem = D2_std / np.sqrt(len(D2_list))  # Error estándar de la media

print(f"\n📊 Estadísticos descriptivos:")
print(f"   Media: {D2_mean:.6f}")
print(f"   Mediana: {D2_median:.6f}")
print(f"   Desviación estándar: {D2_std:.6f}")
print(f"   Error estándar de la media: {D2_sem:.6f}")
print(f"   IC 95%: [{D2_ci_low:.6f}, {D2_ci_high:.6f}]")
print(f"   Rango: [{np.min(D2_list):.6f}, {np.max(D2_list):.6f}]")

# Test de normalidad (Shapiro-Wilk)
from scipy.stats import shapiro
shapiro_stat, shapiro_p = shapiro(D2_list)
print(f"\n📋 Test de normalidad (Shapiro-Wilk):")
print(f"   Estadístico W = {shapiro_stat:.4f}")
print(f"   p-valor = {shapiro_p:.4f}")
print(f"   Distribución {'normal' if shapiro_p > 0.05 else 'no normal'} (α=0.05)")

# ------------------------------------------------------------------------------
# ANÁLISIS DEL SFF Y RAMPA
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🔷 ANÁLISIS DEL SPECTRAL FORM FACTOR")
print(f"{'='*70}")

# Cargar t_values (los generamos de nuevo)
t_values = np.logspace(-1.5, np.log10(3*np.pi), 500)
K_avg = K_total / M_completed

# ------------------------------------------------------------------------------
# DETECCIÓN AUTOMÁTICA DEL DIP Y RANGO ÓPTIMO
# ------------------------------------------------------------------------------
def detect_optimal_ramp_range(t_values, K_values):
    """Detecta el rango óptimo de la rampa basado en curvatura mínima"""

    log_t = np.log(t_values)
    log_K = np.log(K_values)

    # Suavizado con spline
    spline = UnivariateSpline(log_t, log_K, s=len(t_values)*0.02)
    log_t_fine = np.linspace(log_t[0], log_t[-1], 1000)
    log_K_fine = spline(log_t_fine)

    # Detectar dip
    idx_dip = np.argmin(log_K_fine)
    t_dip = np.exp(log_t_fine[idx_dip])
    K_dip = np.exp(log_K_fine[idx_dip])

    # Calcular curvatura
    first_deriv = np.gradient(log_K_fine, log_t_fine)
    second_deriv = np.gradient(first_deriv, log_t_fine)
    curvature = np.abs(second_deriv)
    curvature = curvature / np.max(curvature)  # normalizar

    # Encontrar región de mínima curvatura después del dip
    post_dip_indices = np.where(log_t_fine > log_t_fine[idx_dip])[0]

    if len(post_dip_indices) > 0:
        # Buscar región con curvatura < 0.2 * max
        low_curvature = []
        current_region = []

        for idx in post_dip_indices:
            if curvature[idx] < 0.2:
                current_region.append(idx)
            else:
                if len(current_region) > 10:  # mínimo 10 puntos
                    low_curvature.append(current_region)
                current_region = []

        if len(current_region) > 10:
            low_curvature.append(current_region)

        if low_curvature:
            # Tomar la región más larga
            longest_region = max(low_curvature, key=len)
            idx_start = longest_region[0]
            idx_end = longest_region[-1]

            t_min_ramp = np.exp(log_t_fine[idx_start])
            t_max_ramp = np.exp(log_t_fine[idx_end])
        else:
            # Fallback a heurística
            t_min_ramp = max(1.2 * t_dip, 0.5)
            t_max_ramp = 0.7 * T_HEISENBERG
    else:
        t_min_ramp = max(1.2 * t_dip, 0.5)
        t_max_ramp = 0.7 * T_HEISENBERG

    ramp_mask = (t_values > t_min_ramp) & (t_values < t_max_ramp)

    return t_dip, K_dip, ramp_mask, {
        't_min': t_min_ramp,
        't_max': t_max_ramp,
        'method': 'curvature' if 'low_curvature' in locals() and low_curvature else 'heuristic'
    }

# Detectar parámetros
t_dip, K_dip, ramp_mask, ramp_info = detect_optimal_ramp_range(t_values, K_avg)

print(f"\n📐 Parámetros detectados:")
print(f"   t_dip = {t_dip:.4f}")
print(f"   K_dip = {K_dip:.6f}")
print(f"   Rango rampa: [{ramp_info['t_min']:.4f}, {ramp_info['t_max']:.4f}]")
print(f"   Método: {ramp_info['method']}")
print(f"   Puntos en rampa: {np.sum(ramp_mask)}")

# ------------------------------------------------------------------------------
# AJUSTE DE LA RAMPA CON BOOTSTRAP
# ------------------------------------------------------------------------------
log_t_ramp = np.log(t_values[ramp_mask])
log_K_ramp = np.log(K_avg[ramp_mask])

# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(log_t_ramp, log_K_ramp)
gamma = slope
gamma_error = std_err
r_squared = r_value**2

# Bootstrap para error robusto
n_bootstrap = 10000
bootstrap_slopes = []

for _ in range(n_bootstrap):
    indices = np.random.choice(len(log_t_ramp), len(log_t_ramp), replace=True)
    log_t_sample = log_t_ramp[indices]
    log_K_sample = log_K_ramp[indices]

    try:
        s, _, _, _, _ = linregress(log_t_sample, log_K_sample)
        bootstrap_slopes.append(s)
    except:
        continue

bootstrap_slopes = np.array(bootstrap_slopes)
gamma_bootstrap_mean = np.mean(bootstrap_slopes)
gamma_bootstrap_std = np.std(bootstrap_slopes)
gamma_ci_low, gamma_ci_high = np.percentile(bootstrap_slopes, [2.5, 97.5])

print(f"\n📈 Ajuste de la rampa (γ):")
print(f"   γ = {gamma:.6f} ± {gamma_error:.6f} (error estándar)")
print(f"   Bootstrap: γ = {gamma_bootstrap_mean:.6f} ± {gamma_bootstrap_std:.6f}")
print(f"   IC 95% (bootstrap): [{gamma_ci_low:.6f}, {gamma_ci_high:.6f}]")
print(f"   R² = {r_squared:.6f}")
print(f"   p-valor = {p_value:.6e}")

# ------------------------------------------------------------------------------
# CÁLCULO DE LA ANOMALÍA η = γ - D₂
# ------------------------------------------------------------------------------
eta = gamma - D2_mean
eta_error = np.sqrt(gamma_error**2 + D2_sem**2)

print(f"\n🔷 ANOMALÍA η = γ - D₂:")
print(f"   η = {eta:.6f} ± {eta_error:.6f}")
print(f"   Interpretación: Desviación de ergodicidad completa")

# ------------------------------------------------------------------------------
# VERIFICACIÓN DE FASE NEE
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🔷 VERIFICACIÓN DE FASE NEE")
print(f"{'='*70}")

criterios = {
    'D₂ < 0.5': D2_mean < 0.5,
    'γ < 0.8': gamma < 0.8,
    'η > 0.05': eta > 0.05,
    'R² > 0.8': r_squared > 0.8
}

for criterio, cumplido in criterios.items():
    print(f"   {criterio}: {'✅' if cumplido else '❌'}")

if all(criterios.values()):
    print("\n✅ **CONCLUSIÓN: FASE NEE CONFIRMADA**")
    print("   El sistema presenta todas las características de una fase extendida no-ergódica:")
    print("   - Dimensión fractal reducida (D₂ < 0.5)")
    print("   - Rampa subdifusiva (γ < 0.8)")
    print("   - Anomalía positiva (η > 0.05)")
    print("   - Ajuste de alta calidad (R² > 0.8)")
else:
    print("\n⚠️ **CONCLUSIÓN: FASE NEE NO CONFIRMADA**")
    print("   Algunos criterios no se cumplen. Verificar parámetros.")

# ------------------------------------------------------------------------------
# GRÁFICA PRL COMPLETA (4 PANELES)
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🎨 GENERANDO FIGURA PRL")
print(f"{'='*70}")

fig = plt.figure(figsize=(16, 12))

# ------------------------------------------------------------------------------
# PANEL 1: SFF CON RAMPA
# ------------------------------------------------------------------------------
ax1 = plt.subplot(2, 2, 1)

# SFF promedio
ax1.loglog(t_values, K_avg, 'b-', linewidth=2, label=f'SFF promedio (M={M_completed})', zorder=5)

# Rampa GUE teórica
t_gue = np.linspace(t_values[0], T_HEISENBERG, 200)
K_gue = t_gue / T_HEISENBERG * K_dip * (T_HEISENBERG / t_dip)
ax1.loglog(t_gue, K_gue, 'k--', alpha=0.5, linewidth=1.5, label='GUE teórico (γ=1)', zorder=4)

# Ajuste NEE
t_fit = t_values[ramp_mask]
K_fit = np.exp(intercept) * t_fit**gamma
ax1.loglog(t_fit, K_fit, 'r-', linewidth=2.5,
           label=rf'NEE: γ = {gamma:.3f}±{gamma_error:.3f}', zorder=6)

# Líneas de referencia
ax1.axvline(x=t_dip, color='orange', linestyle='--', alpha=0.7, linewidth=1.5,
            label=f'Dip t={t_dip:.3f}', zorder=3)
ax1.axvline(x=T_HEISENBERG, color='red', linestyle=':', linewidth=2,
            label=r'$t_H = 2\pi$', zorder=3)
ax1.axhline(y=1.0, color='green', linestyle=':', alpha=0.5, linewidth=1.5, zorder=3)

# Sombreado del rango de la rampa
ax1.axvspan(ramp_info['t_min'], ramp_info['t_max'], alpha=0.1, color='yellow', label='Rango rampa')

ax1.set_xlabel('Tiempo $t$', fontsize=12)
ax1.set_ylabel('$\\langle K(t) \\rangle$', fontsize=12)
ax1.set_title('(a) Spectral Form Factor: Rampa Fraccionaria', fontsize=12, fontweight='bold')
ax1.legend(loc='lower right', fontsize=9, framealpha=0.9)
ax1.grid(True, alpha=0.3, which='both')
ax1.set_xlim([t_values[0], t_values[-1]])
ax1.set_ylim([np.min(K_avg)*0.5, 2.0])

# ------------------------------------------------------------------------------
# PANEL 2: HISTOGRAMA DE D₂
# ------------------------------------------------------------------------------
ax2 = plt.subplot(2, 2, 2)

n_bins = int(np.sqrt(len(D2_list)) * 2)
counts, bins, patches = ax2.hist(D2_list, bins=n_bins, color='steelblue',
                                  edgecolor='black', alpha=0.7, density=True)

# Ajuste de distribución normal
x_norm = np.linspace(D2_mean - 4*D2_std, D2_mean + 4*D2_std, 200)
y_norm = norm.pdf(x_norm, D2_mean, D2_std)
ax2.plot(x_norm, y_norm, 'r-', linewidth=2, label='Ajuste normal')

# Líneas de estadísticos
ax2.axvline(x=D2_mean, color='red', linewidth=2, label=f'Media = {D2_mean:.4f}')
ax2.axvline(x=D2_ci_low, color='red', linestyle='--', alpha=0.7, linewidth=1.5)
ax2.axvline(x=D2_ci_high, color='red', linestyle='--', alpha=0.7, linewidth=1.5,
            label='IC 95%')

ax2.set_xlabel('$D_2$', fontsize=12)
ax2.set_ylabel('Densidad de probabilidad', fontsize=12)
ax2.set_title('(b) Distribución de Dimensión Fractal', fontsize=12, fontweight='bold')
ax2.legend(loc='upper right', fontsize=9)
ax2.grid(True, alpha=0.3)

# Texto con estadísticos
stats_text = f'μ = {D2_mean:.4f}\nσ = {D2_std:.4f}\nSEM = {D2_sem:.4f}'
ax2.text(0.05, 0.95, stats_text, transform=ax2.transAxes, fontsize=10,
         verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

# ------------------------------------------------------------------------------
# PANEL 3: CONVERGENCIA DE D₂
# ------------------------------------------------------------------------------
ax3 = plt.subplot(2, 2, 3)

cumulative_mean = [np.mean(D2_list[:i+1]) for i in range(len(D2_list))]
cumulative_std = [np.std(D2_list[:i+1]) for i in range(len(D2_list))]
cumulative_sem = [s/np.sqrt(i+1) for i, s in enumerate(cumulative_std)]

x_vals = range(1, len(D2_list)+1)

ax3.errorbar(x_vals, cumulative_mean, yerr=cumulative_sem, fmt='o-',
             color='darkgreen', markersize=3, capsize=2, linewidth=1.5,
             label='Media acumulada ± SEM')

ax3.axhline(y=D2_mean, color='red', linestyle='--', linewidth=1.5,
            label=f'Límite: {D2_mean:.4f}')
ax3.fill_between(x_vals,
                  [D2_mean - 2*D2_sem]*len(x_vals),
                  [D2_mean + 2*D2_sem]*len(x_vals),
                  color='red', alpha=0.1, label='IC 95% de la media')

ax3.set_xlabel('Número de realizaciones $M$', fontsize=12)
ax3.set_ylabel('$D_2$ acumulado', fontsize=12)
ax3.set_title('(c) Convergencia de la Dimensión Fractal', fontsize=12, fontweight='bold')
ax3.legend(loc='upper right', fontsize=9)
ax3.grid(True, alpha=0.3)
ax3.set_xlim([1, len(D2_list)])

# ==============================================================================
# PANEL 4 CORREGIDO (sin errores de LaTeX)
# ==============================================================================

# ... (todo el código anterior igual hasta el Panel 4)

# ------------------------------------------------------------------------------
# PANEL 4: RESUMEN DE PARÁMETROS (VERSIÓN CORREGIDA)
# ------------------------------------------------------------------------------
ax4 = plt.subplot(2, 2, 4)
ax4.axis('off')

# Texto sin comandos LaTeX problemáticos
info_text = '\n'.join([
    'HAMILTONIANO Z/6Z: RESULTADOS',
    '----------------------------------------',
    'Parámetros fundamentales:',
    f'epsilon_c = π√2 = {EPSILON_CRITICAL:.6f}',
    f'ν = {NU_EXPONENT} (Kato-Rellich bound)',
    'Máscara modular: χ₀⁽⁶⁾(d) ∈ {1,5}',
    f'N = {N_SIZE}, M = {M_completed}',
    '',
    'Resultados experimentales:',
    f'D₂ = {D2_mean:.4f} ± {D2_std:.4f}',
    f'γ  = {gamma:.4f} ± {gamma_error:.4f}',
    f'η  = {eta:.4f} ± {eta_error:.4f}',
    f'R² = {r_squared:.4f}',
    '',
    'Verificación NEE:',
    f'D₂ < 0.5: {"✓" if D2_mean < 0.5 else "✗"}',
    f'γ < 0.8: {"✓" if gamma < 0.8 else "✗"}',
    f'η > 0.05: {"✓" if eta > 0.05 else "✗"}',
    f'R² > 0.8: {"✓" if r_squared > 0.8 else "✗"}',
    '',
    f'FASE NEE: {"CONFIRMADA" if all(criterios.values()) else "NO CONFIRMADA"}'
])

props = dict(boxstyle='round', facecolor='wheat', alpha=0.9, edgecolor='black', linewidth=1)
ax4.text(0.05, 0.95, info_text, transform=ax4.transAxes, fontsize=11,
         verticalalignment='top', horizontalalignment='left',
         fontfamily='monospace', bbox=props)
ax4.set_title('(d) Resumen de Validación', fontsize=12, fontweight='bold')

# ... (resto del código igual)

plt.suptitle(f'Validación NEE: Hamiltoniano ℤ/6ℤ (N={N_SIZE}, M={M_completed})',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('PRL_Figure_Final.png', dpi=300, bbox_inches='tight')
plt.show()

print("\n✅ Figura guardada como 'PRL_Figure_Final.png'")

# ------------------------------------------------------------------------------
# EXPORTAR RESULTADOS PARA EL ARTÍCULO
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("📋 EXPORTANDO RESULTADOS PARA EL ARTÍCULO")
print(f"{'='*70}")

# Resultados en formato LaTeX
latex_table = f"""
\\begin{{table}}[h]
\\caption{{Resultados de la validación NEE para el Hamiltoniano $\\hat{{H}}_{{\\text{{mod}}}}$ (N={N_SIZE}, M={M_completed})}}
\\label{{tab:resultados}}
\\begin{{tabular}}{{lcc}}
\\hline
\\textbf{{Magnitud}} & \\textbf{{Valor}} & \\textbf{{Interpretación}} \\\\
\\hline
$D_2$ (dimensión fractal) & ${D2_mean:.4f} \\pm {D2_std:.4f}$ & Soporte multifractal reducido \\\\
$\\gamma$ (exponente de rampa) & ${gamma:.4f} \\pm {gamma_error:.4f}$ & Difusión subdifusiva \\\\
$\\eta = \\gamma - D_2$ & ${eta:.4f} \\pm {eta_error:.4f}$ & Anomalía de retrodispersión \\\\
$R^2$ del ajuste & ${r_squared:.4f}$ & Calidad del ajuste \\\\
$t_{{\\text{{dip}}}}$ & ${t_dip:.4f}$ & Fin del régimen no universal \\\\
\\hline
\\end{{tabular}}
\\end{{table}}
"""

print("\n📄 Tabla LaTeX para el artículo:")
print(latex_table)

# Guardar resultados en JSON
results_dict = {
    'D2': {
        'mean': float(D2_mean),
        'std': float(D2_std),
        'median': float(D2_median),
        'ci_low': float(D2_ci_low),
        'ci_high': float(D2_ci_high),
        'sem': float(D2_sem),
        'list': [float(x) for x in D2_list]
    },
    'gamma': {
        'value': float(gamma),
        'error': float(gamma_error),
        'bootstrap_mean': float(gamma_bootstrap_mean),
        'bootstrap_std': float(gamma_bootstrap_std),
        'ci_low': float(gamma_ci_low),
        'ci_high': float(gamma_ci_high),
        'r_squared': float(r_squared)
    },
    'eta': {
        'value': float(eta),
        'error': float(eta_error)
    },
    'parameters': {
        'N': N_SIZE,
        'M': M_completed,
        'epsilon': float(EPSILON_CRITICAL),
        'nu': NU_EXPONENT,
        't_dip': float(t_dip),
        't_heisenberg': float(T_HEISENBERG)
    },
    'timestamp': datetime.now().isoformat()
}

with open('resultados_prl.json', 'w') as f:
    json.dump(results_dict, f, indent=2)

print("\n✅ Resultados guardados en 'resultados_prl.json'")

# ------------------------------------------------------------------------------
# RESUMEN FINAL
# ------------------------------------------------------------------------------
print(f"\n{'='*70}")
print("🎯 RESUMEN FINAL PARA PRL")
print(f"{'='*70}")
print(f"""
📊 **RESULTADOS DEFINITIVOS**

Dimensión fractal:        D₂ = {D2_mean:.4f} ± {D2_std:.4f}
Exponente de rampa:       γ  = {gamma:.4f} ± {gamma_error:.4f}
Anomalía:                 η  = {eta:.4f} ± {eta_error:.4f}
Calidad del ajuste:       R² = {r_squared:.4f}

🔬 **VERIFICACIÓN DE FASE NEE: {'✅ CONFIRMADA' if all(criterios.values()) else '⚠️ NO CONFIRMADA'}**

📁 Archivos generados:
   - PRL_Figure_Final.png (figura principal)
   - resultados_prl.json (datos numéricos)
   - Tabla LaTeX (para el artículo)

⏱️  Timestamp: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
{'='*70}
""")

# ------------------------------------------------------------------------------
# VERIFICACIÓN FINAL DE CONSISTENCIA
# ------------------------------------------------------------------------------
print("\n🔍 VERIFICACIÓN DE CONSISTENCIA CON LA TEORÍA:")
print("-"*50)

# Comparación con predicciones teóricas
if 0.23 < D2_mean < 0.25:
    print(f"✅ D₂ = {D2_mean:.4f} está en el rango teórico esperado (0.23-0.25)")
else:
    print(f"⚠️ D₂ = {D2_mean:.4f} fuera del rango teórico esperado")

if 0.30 < gamma < 0.40:
    print(f"✅ γ = {gamma:.4f} está en el rango teórico esperado (0.30-0.40)")
else:
    print(f"⚠️ γ = {gamma:.4f} fuera del rango teórico esperado")

if eta > 0.05:
    print(f"✅ η = {eta:.4f} > 0.05: anomalía positiva confirmada")
else:
    print(f"⚠️ η = {eta:.4f} < 0.05: anomalía débil")

print("\n" + "="*70)
# Out:
# ======================================================================
# 📊 ANÁLISIS FINAL: ENSAMBLE ℤ/6ℤ (N=15000, M=100)
# ======================================================================
#
# 📈 Realizaciones completadas: 100/100
#
# ======================================================================
# 🔷 ANÁLISIS DE DIMENSIÓN FRACTAL D₂
# ======================================================================
#
# 📊 Estadísticos descriptivos:
#    Media: 0.243383
#    Mediana: 0.243405
#    Desviación estándar: 0.000550
#    Error estándar de la media: 0.000055
#    IC 95%: [0.242301, 0.244515]
#    Rango: [0.242001, 0.244638]
#
# 📋 Test de normalidad (Shapiro-Wilk):
#    Estadístico W = 0.9917
#    p-valor = 0.7960
#    Distribución normal (α=0.05)
#
# ======================================================================
# 🔷 ANÁLISIS DEL SPECTRAL FORM FACTOR
# ======================================================================
#
# 📐 Parámetros detectados:
#    t_dip = 0.0331
#    K_dip = 0.003178
#    Rango rampa: [0.0671, 9.4248]
#    Método: curvature
#    Puntos en rampa: 434
#
# 📈 Ajuste de la rampa (γ):
#    γ = 0.608631 ± 0.010291 (error estándar)
#    Bootstrap: γ = 0.608417 ± 0.012811
#    IC 95% (bootstrap): [0.583031, 0.633685]
#    R² = 0.890063
#    p-valor = 3.135343e-209
#
# 🔷 ANOMALÍA η = γ - D₂:
#    η = 0.365248 ± 0.010292
#    Interpretación: Desviación de ergodicidad completa
#
# ======================================================================
# 🔷 VERIFICACIÓN DE FASE NEE
# ======================================================================
#    D₂ < 0.5: ✅
#    γ < 0.8: ✅
#    η > 0.05: ✅
#    R² > 0.8: ✅
#
# ✅ **CONCLUSIÓN: FASE NEE CONFIRMADA**
#    El sistema presenta todas las características de una fase extendida no-ergódica:
#    - Dimensión fractal reducida (D₂ < 0.5)
#    - Rampa subdifusiva (γ < 0.8)
#    - Anomalía positiva (η > 0.05)
#    - Ajuste de alta calidad (R² > 0.8)
#
# ======================================================================
# 🎨 GENERANDO FIGURA PRL
# ======================================================================
# ✅ Figura guardada como 'PRL_Figure_Final.png'
#
# ======================================================================
# 📋 EXPORTANDO RESULTADOS PARA EL ARTÍCULO
# ======================================================================
#
# 📄 Tabla LaTeX para el artículo:
#
# \begin{table}[h]
# \caption{Resultados de la validación NEE para el Hamiltoniano $\hat{H}_{\text{mod}}$ (N=15000, M=100)}
# \label{tab:resultados}
# \begin{tabular}{lcc}
# \hline
# \textbf{Magnitud} & \textbf{Valor} & \textbf{Interpretación} \\
# \hline
# $D_2$ (dimensión fractal) & $0.2434 \pm 0.0005$ & Soporte multifractal reducido \\
# $\gamma$ (exponente de rampa) & $0.6086 \pm 0.0103$ & Difusión subdifusiva \\
# $\eta = \gamma - D_2$ & $0.3652 \pm 0.0103$ & Anomalía de retrodispersión \\
# $R^2$ del ajuste & $0.8901$ & Calidad del ajuste \\
# $t_{\text{dip}}$ & $0.0331$ & Fin del régimen no universal \\
# \hline
# \end{tabular}
# \end{table}
#
#
# ✅ Resultados guardados en 'resultados_prl.json'
#
# ======================================================================
# 🎯 RESUMEN FINAL PARA PRL
# ======================================================================
#
# 📊 **RESULTADOS DEFINITIVOS**
#
# Dimensión fractal:        D₂ = 0.2434 ± 0.0005
# Exponente de rampa:       γ  = 0.6086 ± 0.0103
# Anomalía:                 η  = 0.3652 ± 0.0103
# Calidad del ajuste:       R² = 0.8901
#
# 🔬 **VERIFICACIÓN DE FASE NEE: ✅ CONFIRMADA**
#
# 📁 Archivos generados:
#    - PRL_Figure_Final.png (figura principal)
#    - resultados_prl.json (datos numéricos)
#    - Tabla LaTeX (para el artículo)
#
# ⏱️  Timestamp: 2026-03-09 19:11:03
# ======================================================================
#
#
# 🔍 VERIFICACIÓN DE CONSISTENCIA CON LA TEORÍA:
# --------------------------------------------------
# ✅ D₂ = 0.2434 está en el rango teórico esperado (0.23-0.25)
# ⚠️ γ = 0.6086 fuera del rango teórico esperado
# ✅ η = 0.3652 > 0.05: anomalía positiva confirmada
#
# ======================================================================
